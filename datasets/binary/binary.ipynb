# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Mai 30

@author: yaning
"""

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf)
import pickle
import torch
path = "/home/yaning/Documents/"

# %%
(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# %%
binary_x_train = []
for i in range(x_train.shape[0]):
    binary_x_train.append(np.where(x_train[i] != 0, 1, 0))

# %%
binary_x_train = torch.tensor(binary_x_train)

# %%
binary_x_train.shape
# Out:
# torch.Size([60000, 28, 28, 1])

# %%
plt.imshow(fire_data[5,...,501], cmap='Blues')

# %%
45+189
# Out:
# 234

# %%
# form an shape (5000, 3) array with 5000 time points and 3 input neurons
# every fire is 45-50 cycles, 
pointCount = 6000
start_tstep = 500
# one_cycle = np.concatenate((np.ones(45, dtype=bool), np.zeros(189, dtype=bool)))
one_cycle = np.ones(234)
firing_duration = 45+189
# 23*(45+189) = 5382
total_time = 5382


non_fire_array = np.zeros(pointCount, dtype=bool)

# %%
fire_seq = np.tile(one_cycle, 23)
fire_array = non_fire_array.copy()
fire_array[start_tstep:start_tstep+len(fire_seq)] = fire_seq

# %%
# only take first 20 pictures
binary_x_train = binary_x_train[:20]

# %%
fire_array = torch.tensor(fire_array)
non_fire_array = torch.tensor(non_fire_array)

# %%
plt.plot(fire_array)

# %%
binary_x_train.shape
# Out:
# torch.Size([20, 28, 28, 1])

# %%
fire_data = np.zeros((20,28,28,6000), dtype=bool)
for i in range(binary_x_train.shape[0]):
    for x in range(binary_x_train.shape[1]):
        for y in range(binary_x_train.shape[2]):
            if binary_x_train[i,x,y] == 0:
                fire_data[i,x,y] = non_fire_array
            else:
                fire_data[i,x,y] = fire_array
# Out:
# /tmp/ipykernel_643316/3632697730.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   fire_data[i,x,y] = non_fire_array
# /tmp/ipykernel_643316/3632697730.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   fire_data[i,x,y] = fire_array

# %%
fire_data.shape
# Out:
# (20, 28, 28, 6000)

# %%
fire_data = torch.tensor(fire_data)

# %%
plt.plot(binary_x_train[4].view(-1))

# %%
plt.plot(fire_data[4,...,1025].view(-1))

# %%
fire_data = np.array(fire_data)
# Out:
# /tmp/ipykernel_643316/2878838989.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   fire_data = np.array(fire_data)

# %%
with open(path + "binary_fire_date.pkl", "wb") as f:
    pickle.dump(fire_data, f)
