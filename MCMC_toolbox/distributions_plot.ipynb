# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Dec 19

@author: yaning
"""

import numpy as np
import importlib
import matplotlib.pyplot as plt
import torch
from torch.distributions import Normal, Uniform
from tqdm import tqdm

# functions and classes that i wrote
import without_learning.NN.Receptors as Receptors
import without_learning.NN.Network as Network

importlib.reload(Receptors)
importlib.reload(Network)

np.set_printoptions(threshold=np.inf)
path = "/home/yaning/Documents/Spiking_NN/without_learning/"

# %%
infer_names = Receptors.LigandGatedChannelFactory.infer_names
samples = np.load(path + "samples.npy") 
samples_pure = np.load(path + "pure_samples.npy")

# %%
samples.shape
# Out:
# (15, 19)

# %%
cut_samples = samples[:]
Tcut_samples = cut_samples.T

# %%
np.mean(cut_samples, axis=0)
# Out:
# array([ 0.49786967,  0.6309982 ,  0.523957  ,  0.59533244,  0.62537706,
#         0.6983955 ,  0.4721104 ,  0.6315349 ,  0.65817803,  0.69851345,
#        29.05518   , 28.145641  , 30.516598  , 27.47422   , 25.063454  ,
#        31.064646  , 33.672935  , 30.70122   , 28.155975  ], dtype=float32)

# %%
cut_pure_samples = samples_pure[:]
Tcut_pure_samples = cut_pure_samples.T

# %%
for i, data in enumerate(Tcut_pure_samples):
    plt.figure()  # Create a new figure for each plot
    plt.hist(data, bins=25, edgecolor='black')
    plt.title(f'Histogram for Array {infer_names[i]}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()
