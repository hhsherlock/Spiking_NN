# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Dec 19

@author: yaning
"""

import numpy as np
import importlib
import matplotlib.pyplot as plt
import torch
from torch.distributions import Normal, Uniform
from tqdm import tqdm

# functions and classes that i wrote
import without_learning.NN.Receptors as Receptors
import without_learning.NN.Network as Network

importlib.reload(Receptors)
importlib.reload(Network)

np.set_printoptions(threshold=np.inf)
path = "/home/yaning/Documents/Spiking_NN/without_learning/"

# %%
infer_names = Receptors.LigandGatedChannelFactory.infer_names
samples = np.load(path + "MCMC_samples/factor_50.npy") 
samples_pure = np.load(path + "MCMC_samples/factor_50_pure.npy")

# %%
samples.shape
# Out:
# (1500, 19)

# %%
cut_samples = samples[1000:]
Tcut_samples = cut_samples.T

# %%
np.mean(cut_samples, axis=0)
# Out:
# array([ 0.63032466,  0.622835  ,  0.59995925,  0.6325449 ,  0.63015485,
#         0.6264109 ,  0.6262229 ,  0.60490894,  0.63365614,  0.63642794,
#        50.        , 50.        , 50.        , 50.        , 50.        ,
#        50.        , 50.        , 50.        , 50.        ], dtype=float32)

# %%
cut_pure_samples = samples_pure[1000:]
Tcut_pure_samples = cut_pure_samples.T

# %%
for i, data in enumerate(Tcut_samples):
    plt.figure()  # Create a new figure for each plot
    plt.hist(data, bins=25, edgecolor='black')
    plt.title(f'Histogram for Array {infer_names[i]}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()
